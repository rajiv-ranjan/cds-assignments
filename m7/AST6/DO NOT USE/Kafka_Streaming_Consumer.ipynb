# %% [markdown]
# # Advanced Certification Program in Computational Data Science
# ## A program by IISc and TalentSprint
# ### Apache Kafka Streaming (This particular notebook is part of Assignment 7)

# %% [markdown]
# ### Install Confluent kafka

# %%
# !pip install confluent_kafka
# Out:
# Requirement already satisfied: confluent_kafka in /usr/local/lib/python3.10/dist-packages (2.6.0)

# %% [markdown]
# Specify your own `BROKERS`, `USERNAME`, `PASSWORD` and `TOPIC` in the below script files.

# %% [markdown]
# ### Example 1: Send and receive messages

# %% [markdown]
# Here we create two files one is `producer1.py` and another one is `consumer1.py`(in Consumer notebook). Producer will send messages to a topic and consumer will read these messages in real-time from that particular topic and displays the message along with its word count and an `ALERT` message if the number of words exceeds 6.

# %% [markdown]
# #### Write Consumer file
#
# Here we create a consumer file that will read messages from the specified `topic`.

# %%
# %%writefile consumer1.py

import sys
import os

from confluent_kafka import Consumer, KafkaException, KafkaError

# Specify BROKERS, USERNAME, PASSWORD and TOPIC
# Use the same credentials from Assignment 7
brokers = "dory-01.srvs.cloudkafka.com:9094, dory-02.srvs.cloudkafka.com:9094, dory-03.srvs.cloudkafka.com:9094"
username = "pikjfbyx"
password = "4iUJFg-WrwqDrae9vCJ4oen99wCNXpVY"
topic = "pikjfbyx-default"

# Set the path for the user-defined modules so that they can be directly imported into the python program
os.environ['CLOUDKARAFKA_BROKERS']= brokers
os.environ['CLOUDKARAFKA_USERNAME']= username
os.environ['CLOUDKARAFKA_PASSWORD']= password
os.environ['CLOUDKARAFKA_TOPIC']= topic

if __name__ == '__main__':
    topics = os.environ['CLOUDKARAFKA_TOPIC'].split(",")

    # Consumer configuration
    conf = {
        'bootstrap.servers': os.environ['CLOUDKARAFKA_BROKERS'],                # Specify kafka servers
        'group.id': "%s-consumer" % os.environ['CLOUDKARAFKA_USERNAME'],
        'session.timeout.ms': 6000,                                             # The consumer sends periodic heartbeats to indicate its liveness to the broker
        'default.topic.config': {'auto.offset.reset': 'smallest'},
        'security.protocol': 'SASL_SSL',
	      'sasl.mechanisms': 'SCRAM-SHA-512',
        'sasl.username': os.environ['CLOUDKARAFKA_USERNAME'],
        'sasl.password': os.environ['CLOUDKARAFKA_PASSWORD']
    }

    c = Consumer(**conf)
    c.subscribe(topics)
    try:
        while True:                       # read data continuously
            msg = c.poll(timeout=1.0)
            if msg is None:
                continue
            if msg.error():
                # Error or event
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    # End of partition event
                    sys.stderr.write('%% %s [%d] reached end at offset %d\n' %
                                     (msg.topic(), msg.partition(), msg.offset()))
                elif msg.error():
                    # Error
                    raise KafkaException(msg.error())
            else:
                # Proper message
                # sys.stderr.write('%% %s [%d] at offset %d with key %s:\n' % (msg.topic(), msg.partition(), msg.offset(), str(msg.key())))
                msg_ = msg.value()
                n = len(msg_.split())
                if n<=6:
                  print(msg.value())
                  print('Number of words: %d'%n)
                if n>6:
                  print('ALERT: Word limit exceeds!!')
                print("")

    except KeyboardInterrupt:
        sys.stderr.write('%% Aborted by user\n')

    # Close down consumer to commit final offsets.
    c.close()
# Out:
# Writing consumer1.py

# %% [markdown]
# #### Run consumer file

# %% [markdown]
# The consumer will keep on running and will show output whenever the producer sends some data to that topic.
#
# <font color='blue'>Before executing the below cell ensure that you created the CloudKarafka account and specified the credentials.</font>

# %%
# !python consumer1.py
# Out:
# %6|1729146963.528|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 3896ms in state UP)
# %6|1729146963.773|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 25ms in state UP, 1 identical error(s) suppressed)
# %6|1729146963.917|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 68ms in state UP)
# %4|1729146963.941|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 60ms in state UP)
# %6|1729146964.156|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 1 identical error(s) suppressed)
# %4|1729146964.184|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 41ms in state UP, 1 identical error(s) suppressed)
# %6|1729146998.619|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 8 identical error(s) suppressed)
# %6|1729146999.700|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 8 identical error(s) suppressed)
# %6|1729147001.566|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 8 identical error(s) suppressed)
# %% Aborted by user

# %% [markdown]
# For next example **create a new topic** on CloudKarafka and use its topic name. To create a topic, please refer to step 11 in this [document](https://cdn.iisc.talentsprint.com/CDS/CloudKarafka.pdf).

# %% [markdown]
# ### Example 2: Compute the rolling mean of last three insertions

# %% [markdown]
# Here we create two files one is `producer2.py` and another one is `consumer2.py`(in Consumer notebook). Producer will send data to a topic and consumer will read these records in real-time from that particular topic and displays the rolling mean of the last three insertions. Only the added numbers will be displayed for the first two insertions.

# %% [markdown]
# #### Write Consumer file
#
# Here we create a consumer file that will read messages from the specified `topic`.

# %%
# %%writefile consumer2.py

import sys
import os

from confluent_kafka import Consumer, KafkaException, KafkaError

# Specify BROKERS, USERNAME, PASSWORD and TOPIC
# Use the same credentials from Assignment 7

# Set the path for the user-defined modules so that they can be directly imported into the python program
brokers = "dory-01.srvs.cloudkafka.com:9094, dory-02.srvs.cloudkafka.com:9094, dory-03.srvs.cloudkafka.com:9094"
username = "pikjfbyx"
password = "4iUJFg-WrwqDrae9vCJ4oen99wCNXpVY"
topic = "pikjfbyx-default"

# Set the path for the user-defined modules so that they can be directly imported into the python program
os.environ['CLOUDKARAFKA_BROKERS']= brokers
os.environ['CLOUDKARAFKA_USERNAME']= username
os.environ['CLOUDKARAFKA_PASSWORD']= password
os.environ['CLOUDKARAFKA_TOPIC']= topic

if __name__ == '__main__':
    topics = os.environ['CLOUDKARAFKA_TOPIC'].split(",")

    # Consumer configuration
    conf = {
        'bootstrap.servers': os.environ['CLOUDKARAFKA_BROKERS'],                # Specify kafka servers
        'group.id': "%s-consumer" % os.environ['CLOUDKARAFKA_USERNAME'],
        'session.timeout.ms': 6000,                                             # The consumer sends periodic heartbeats to indicate its liveness to the broker
        'default.topic.config': {'auto.offset.reset': 'smallest'},
        'security.protocol': 'SASL_SSL',
	      'sasl.mechanisms': 'SCRAM-SHA-512',
        'sasl.username': os.environ['CLOUDKARAFKA_USERNAME'],
        'sasl.password': os.environ['CLOUDKARAFKA_PASSWORD']
    }

    c = Consumer(**conf)
    c.subscribe(topics)
    numbers = []
    count = 1
    window = 3                              # rolling window
    try:
        while True:                    # read data continuously
            msg = c.poll(timeout=1.0)
            if msg is None:
                continue
            if msg.error():
                # Error or event
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    # End of partition event
                    sys.stderr.write('%% %s [%d] reached end at offset %d\n' %
                                     (msg.topic(), msg.partition(), msg.offset()))
                elif msg.error():
                    # Error
                    raise KafkaException(msg.error())
            else:
                # Proper message
                # sys.stderr.write('%% %s [%d] at offset %d with key %s:\n' % (msg.topic(), msg.partition(), msg.offset(), str(msg.key())))
                msg_ = msg.value()                             # read data
                num = float(msg_.decode("utf-8"))              # decode from bytes and convert it into float type
                numbers.append(num)                            # add current data to list
                if count<window:
                  print(num)
                if count>=window:
                  print(num)
                  mean = sum(numbers[-3:])/3                   # calculate rolling mean
                  print("mean of last three insertions: {}".format(mean))
                print("")
                count += 1

    except KeyboardInterrupt:
        sys.stderr.write('%% Aborted by user\n')

    # Close down consumer to commit final offsets.
    c.close()
# Out:
# Writing consumer2.py

# %% [markdown]
# #### Run Consumer file

# %% [markdown]
# The consumer will keep on running and will show output whenever the producer sends some data to that topic.
#
# <font color='blue'>Before executing the below cell ensure that you created the CloudKarafka account and specified the credentials.</font>

# %%
# !python consumer2.py
# Out:
# %6|1729147033.305|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 3985ms in state UP)
# %6|1729147033.501|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 1 identical error(s) suppressed)
# %4|1729147033.540|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 61ms in state UP)
# %6|1729147033.602|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 62ms in state UP)
# %6|1729147033.747|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 41ms in state UP, 1 identical error(s) suppressed)
# %6|1729147033.876|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 1 identical error(s) suppressed)
# %6|1729147065.715|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 8 identical error(s) suppressed)
# %6|1729147066.250|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 8 identical error(s) suppressed)
# %6|1729147073.672|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 9 identical error(s) suppressed)
# %6|1729147096.373|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729147105.661|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147112.085|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147134.690|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147135.678|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147142.106|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147170.521|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147175.670|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147180.025|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147209.251|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147210.196|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147212.823|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147247.950|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147249.064|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 25ms in state UP, 4 identical error(s) suppressed)
# %6|1729147250.058|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147284.978|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147287.456|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147288.722|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147323.303|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147326.512|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147327.150|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147360.509|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147365.257|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 19ms in state UP, 4 identical error(s) suppressed)
# %6|1729147365.370|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147400.368|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147403.683|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147404.818|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147438.898|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147443.178|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147443.498|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147477.821|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147481.241|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147481.677|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147511.691|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729147517.030|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147521.191|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147541.788|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147554.711|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147559.945|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 25ms in state UP, 4 identical error(s) suppressed)
# %6|1729147581.166|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147590.026|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147592.095|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 41ms in state UP, 4 identical error(s) suppressed)
# %6|1729147619.379|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147627.927|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147629.956|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147656.194|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729147660.003|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147667.910|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147693.615|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 24ms in state UP, 4 identical error(s) suppressed)
# %6|1729147697.264|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147703.410|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147731.602|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147735.111|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 26ms in state UP, 4 identical error(s) suppressed)
# %6|1729147742.765|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147761.617|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729147775.117|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147782.770|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147796.912|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147812.795|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729147813.915|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147831.675|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147852.002|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147852.048|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147861.697|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729147882.081|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 22ms in state UP, 3 identical error(s) suppressed)
# %6|1729147888.470|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147901.639|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729147917.451|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147926.900|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147935.833|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147955.386|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147966.673|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147971.788|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729147992.120|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148004.512|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148010.533|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 23ms in state UP, 4 identical error(s) suppressed)
# %6|1729148030.492|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148042.140|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148048.770|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 28ms in state UP, 4 identical error(s) suppressed)
# %6|1729148067.659|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148078.585|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148086.756|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148097.662|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148108.617|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %4|1729148125.590|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148135.577|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148147.059|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148164.652|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148175.220|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148186.363|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148203.524|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148213.075|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148225.586|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 19ms in state UP, 4 identical error(s) suppressed)
# %6|1729148240.073|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148252.760|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148255.594|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148278.691|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148288.399|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148288.900|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148308.696|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148325.977|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148327.436|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 24ms in state UP, 4 identical error(s) suppressed)
# %6|1729148345.118|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148363.084|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %4|1729148363.121|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 40ms in state UP, 4 identical error(s) suppressed)
# %6|1729148384.069|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148399.901|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148401.705|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148422.715|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148437.525|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148441.814|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 109ms in state UP, 4 identical error(s) suppressed)
# %6|1729148461.234|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148474.431|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148481.701|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148500.602|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148511.717|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148514.407|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729148536.521|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %4|1729148551.764|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148554.345|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148574.827|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148590.521|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148592.757|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148613.037|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148629.728|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148630.162|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 19ms in state UP, 4 identical error(s) suppressed)
# %6|1729148649.888|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148665.553|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148666.262|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148687.527|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148704.128|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148704.573|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148717.537|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148739.732|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148743.933|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148755.857|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148779.276|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148779.319|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148785.868|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729148817.218|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %4|1729148817.950|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148824.106|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148854.296|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729148855.909|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148864.048|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148884.384|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729148895.234|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148902.657|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148924.359|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729148933.826|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148939.311|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148962.515|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148971.372|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729148979.233|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149001.447|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149010.326|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149017.059|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149038.540|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149050.140|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149052.519|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149078.142|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149080.140|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729149089.649|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149114.214|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149115.660|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149126.405|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149153.391|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149153.879|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149164.447|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149192.219|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149193.453|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149203.634|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149230.994|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149231.942|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149242.768|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %4|1729149268.235|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149271.964|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149280.252|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149306.199|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 41ms in state UP, 4 identical error(s) suppressed)
# %6|1729149307.655|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149318.925|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149343.685|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149345.688|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149352.730|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149381.508|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149382.759|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729149383.468|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149414.723|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149421.233|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149422.689|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729149450.827|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 41ms in state UP, 4 identical error(s) suppressed)
# %6|1729149460.181|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149461.074|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149488.808|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149494.640|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149497.617|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149527.618|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149534.659|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149534.880|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149567.668|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149571.594|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149574.394|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149607.364|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149611.161|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149611.425|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149641.223|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 76ms in state UP, 3 identical error(s) suppressed)
# ...
# %6|1729149756.508|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149762.491|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149763.082|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149795.383|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149801.988|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149802.280|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149834.946|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 94ms in state UP, 4 identical error(s) suppressed)
# %6|1729149839.175|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149839.693|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149868.953|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149878.108|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149878.613|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149907.931|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149915.716|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149918.599|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %4|1729149946.702|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149948.616|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 3 identical error(s) suppressed)
# %6|1729149955.632|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149985.559|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729149987.779|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729149992.335|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150023.523|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150026.450|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150030.685|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150063.507|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150064.696|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150067.908|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150102.144|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150102.715|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150104.764|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150140.206|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150140.529|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150144.751|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150175.869|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150179.015|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150183.056|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150205.903|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 22ms in state UP, 3 identical error(s) suppressed)
# %6|1729150216.264|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150219.482|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 19ms in state UP, 4 identical error(s) suppressed)
# %6|1729150244.593|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150254.763|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150257.643|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150283.000|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150291.524|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150297.633|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729150321.967|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 22ms in state UP, 4 identical error(s) suppressed)
# %6|1729150330.890|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150335.541|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150360.727|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150368.885|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150371.177|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150390.796|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729150401.240|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729150406.444|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150428.493|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150436.096|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150445.478|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150466.203|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 82ms in state UP, 3 identical error(s) suppressed)
# %6|1729150468.525|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150484.312|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 42ms in state UP, 4 identical error(s) suppressed)
# %6|1729150505.285|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 25ms in state UP, 4 identical error(s) suppressed)
# %6|1729150506.542|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150522.356|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150536.553|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729150542.963|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150558.886|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150574.749|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
# %6|1729150578.875|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150593.432|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-02.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-02.srvs.cloudkafka.com:9094/1: Disconnected (after 20ms in state UP, 4 identical error(s) suppressed)
# %6|1729150608.958|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-01.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-01.srvs.cloudkafka.com:9094/0: Disconnected (after 20ms in state UP, 3 identical error(s) suppressed)
# %6|1729150609.032|FAIL|rdkafka#consumer-1| [thrd:sasl_ssl://dory-03.srvs.cloudkafka.com:9094/bootstrap]: sasl_ssl://dory-03.srvs.cloudkafka.com:9094/2: Disconnected (after 21ms in state UP, 4 identical error(s) suppressed)
